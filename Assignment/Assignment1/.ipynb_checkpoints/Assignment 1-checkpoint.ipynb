# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv("houseData.csv")
data.head(10)
# Out:
#    Id  LotArea Street Neighborhood HouseStyle  YearBuilt CentralAir  \
# 0   1     8450   Pave      CollgCr     2Story       2003          Y
# 1   2     9600   Pave      Veenker     1Story       1976          Y
# 2   3    11250   Pave      CollgCr     2Story       2001          Y
# 3   4     9550   Pave      Crawfor     2Story       1915          Y
# 4   5    14260   Pave      NoRidge     2Story       2000          Y
# 5   6    14115   Pave      Mitchel     1.5Fin       1993          Y
# 6   7    10084   Pave      Somerst     1Story       2004          Y
# 7   8    10382   Pave       NWAmes     2Story       1973          Y
# 8   9     6120   Pave      OldTown     1.5Fin       1931          Y
# 9  10     7420   Pave      BrkSide     1.5Unf       1939          Y
#
#    BedroomAbvGr  Fireplaces GarageType  GarageYrBlt  GarageArea  PoolArea  \
# 0             3           0     Attchd       2003.0         548         0
# ...

# %%
data.drop("Id", axis=1,inplace=True)

# %%
data.count()
# Out:
# LotArea         1460
# Street          1460
# Neighborhood    1460
# HouseStyle      1460
# YearBuilt       1460
# CentralAir      1460
# BedroomAbvGr    1460
# Fireplaces      1460
# GarageType      1379
# GarageYrBlt     1379
# GarageArea      1460
# PoolArea        1460
# PoolQC             7
# Fence            281
# SalePrice       1460
# dtype: int64

# %%
data.shape
# Out:
# (1460, 15)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 15 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   LotArea       1460 non-null   int64
#  1   Street        1460 non-null   object
#  2   Neighborhood  1460 non-null   object
#  3   HouseStyle    1460 non-null   object
#  4   YearBuilt     1460 non-null   int64
#  5   CentralAir    1460 non-null   object
#  6   BedroomAbvGr  1460 non-null   int64
#  7   Fireplaces    1460 non-null   int64
#  8   GarageType    1379 non-null   object
#  9   GarageYrBlt   1379 non-null   float64
#  10  GarageArea    1460 non-null   int64
#  11  PoolArea      1460 non-null   int64
#  12  PoolQC        7 non-null      object
#  13  Fence         281 non-null    object
#  14  SalePrice     1460 non-null   int64
# dtypes: float64(1), int64(7), object(7)
# memory usage: 171.2+ KB

# %%
data.max()
# Out:
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_12420\2904433368.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   data.max()
# LotArea          215245
# Street             Pave
# Neighborhood    Veenker
# HouseStyle         SLvl
# YearBuilt          2010
# CentralAir            Y
# BedroomAbvGr          8
# Fireplaces            3
# GarageYrBlt      2010.0
# GarageArea         1418
# PoolArea            738
# SalePrice        755000
# dtype: object

# %%
data.min()
# Out:
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_12420\927168777.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   data.min()
# LotArea            1300
# Street             Grvl
# Neighborhood    Blmngtn
# HouseStyle       1.5Fin
# YearBuilt          1872
# CentralAir            N
# BedroomAbvGr          0
# Fireplaces            0
# GarageYrBlt      1900.0
# GarageArea            0
# PoolArea              0
# SalePrice         34900
# dtype: object

# %%
data['Street'].value_counts()
# Out:
# Pave    1454
# Grvl       6
# Name: Street, dtype: int64

# %%
Street_count=data["Street"].value_counts()
Street_count.plot(kind="barh")
# Out:
# <AxesSubplot:>

# %%
data['HouseStyle'].value_counts()
# Out:
# 1Story    726
# 2Story    445
# 1.5Fin    154
# SLvl       65
# SFoyer     37
# 1.5Unf     14
# 2.5Unf     11
# 2.5Fin      8
# Name: HouseStyle, dtype: int64

# %%
data["CentralAir"].value_counts()
# Out:
# Y    1365
# N      95
# Name: CentralAir, dtype: int64

# %%
CenterAir_house=data[data["CentralAir"]=='Y']
CenterAir_house
# Out:
#       LotArea Street Neighborhood HouseStyle  YearBuilt CentralAir  \
# 0        8450   Pave      CollgCr     2Story       2003          Y
# 1        9600   Pave      Veenker     1Story       1976          Y
# 2       11250   Pave      CollgCr     2Story       2001          Y
# 3        9550   Pave      Crawfor     2Story       1915          Y
# 4       14260   Pave      NoRidge     2Story       2000          Y
# ...       ...    ...          ...        ...        ...        ...
# 1455     7917   Pave      Gilbert     2Story       1999          Y
# 1456    13175   Pave       NWAmes     1Story       1978          Y
# 1457     9042   Pave      Crawfor     2Story       1941          Y
# 1458     9717   Pave        NAmes     1Story       1950          Y
# 1459     9937   Pave      Edwards     1Story       1965          Y
#
#       BedroomAbvGr  Fireplaces GarageType  GarageYrBlt  GarageArea  PoolArea  \
# 0                3           0     Attchd       2003.0         548         0
# ...

# %%
Sale_price=data[data["SalePrice"]>500000]
Sale_price
# Out:
#       LotArea Street Neighborhood HouseStyle  YearBuilt CentralAir  \
# 178     17423   Pave      StoneBr     1Story       2008          Y
# 440     15431   Pave      NridgHt     1Story       2008          Y
# 691     21535   Pave      NoRidge     2Story       1994          Y
# 769     53504   Pave      StoneBr     2Story       2003          Y
# 803     13891   Pave      NridgHt     2Story       2008          Y
# 898     12919   Pave      NridgHt     1Story       2009          Y
# 1046    16056   Pave      StoneBr     2Story       2005          Y
# 1169    35760   Pave      NoRidge     2Story       1995          Y
# 1182    15623   Pave      NoRidge     2Story       1996          Y
#
#       BedroomAbvGr  Fireplaces GarageType  GarageYrBlt  GarageArea  PoolArea  \
# 178              1           1     Attchd       2009.0        1166         0
# 440              2           2     Attchd       2008.0         672         0
# ...

# %%
Sale_price.shape
# Out:
# (9, 15)

# %%
Build_after=data[data["YearBuilt"]==2000]
Build_after
# Out:
#       LotArea Street Neighborhood HouseStyle  YearBuilt CentralAir  \
# 4       14260   Pave      NoRidge     2Story       2000          Y
# 111      7750   Pave      Gilbert       SLvl       2000          Y
# 131     12224   Pave      Gilbert     2Story       2000          Y
# 180      2117   Pave      Somerst     2Story       2000          Y
# 370      8121   Pave      Gilbert     2Story       2000          Y
# 379      8123   Pave      Gilbert     2Story       2000          Y
# 474      5330   Pave      StoneBr     1Story       2000          Y
# 541     11000   Pave      NoRidge     2Story       2000          Y
# 573      9967   Pave      Gilbert       SLvl       2000          Y
# 610     11050   Pave      CollgCr     2Story       2000          Y
# 623      2117   Pave      Somerst     2Story       2000          Y
# 665     11194   Pave      Gilbert     2Story       2000          Y
# 742      8450   Pave      SawyerW     1Story       2000          Y
# ...

# %%
Build_after.shape
# Out:
# (24, 15)

# %%
##House_Garage_OldTown=data[data["YearBuilt"]>2001 and data["GarageType"]=="Attchd" and data["Neighborhood"]=="OldTown"]
##House_Garage_OldTown

# %%
data.rename(columns={"BedroomAbvGr":"Bedroom", "Neighborhood":" NeighborArea"} , inplace = True)
data.head()
# Out:
#    LotArea Street  NeighborArea HouseStyle  YearBuilt CentralAir  Bedroom  \
# 0     8450   Pave       CollgCr     2Story       2003          Y        3
# 1     9600   Pave       Veenker     1Story       1976          Y        3
# 2    11250   Pave       CollgCr     2Story       2001          Y        3
# 3     9550   Pave       Crawfor     2Story       1915          Y        3
# 4    14260   Pave       NoRidge     2Story       2000          Y        4
#
#    Fireplaces GarageType  GarageYrBlt  GarageArea  PoolArea PoolQC Fence  \
# 0           0     Attchd       2003.0         548         0    NaN   NaN
# 1           1     Attchd       1976.0         460         0    NaN   NaN
# 2           1     Attchd       2001.0         608         0    NaN   NaN
# 3           1     Detchd       1998.0         642         0    NaN   NaN
# 4           1     Attchd       2000.0         836         0    NaN   NaN
#
#    SalePrice
# 0     208500
# 1     181500
# 2     223500
# 3     140000
# ...

# %%
data=data.assign(Sold='N')
data
# Out:
#       LotArea Street  NeighborArea HouseStyle  YearBuilt CentralAir  Bedroom  \
# 0        8450   Pave       CollgCr     2Story       2003          Y        3
# 1        9600   Pave       Veenker     1Story       1976          Y        3
# 2       11250   Pave       CollgCr     2Story       2001          Y        3
# 3        9550   Pave       Crawfor     2Story       1915          Y        3
# 4       14260   Pave       NoRidge     2Story       2000          Y        4
# ...       ...    ...           ...        ...        ...        ...      ...
# 1455     7917   Pave       Gilbert     2Story       1999          Y        3
# 1456    13175   Pave        NWAmes     1Story       1978          Y        3
# 1457     9042   Pave       Crawfor     2Story       1941          Y        4
# 1458     9717   Pave         NAmes     1Story       1950          Y        2
# 1459     9937   Pave       Edwards     1Story       1965          Y        3
#
# ...

# %%
appenddata1={ 
    'LotArea': 9500,
 'Street': "Pave",
 'NeighborArea': "Downtown",
 'HouseStyle': '2Story', 
 'YearBuilt': 2021,
 'CentralAir':'Y',
 'Bedroom': 5,
 'Fireplaces': 1,
 'GarageType': 'Attchd',
 'GarageYrBlt': 2021,
 'GarageArea': 300,
 'PoolArea': 0,
 'PoolQC': 'G',
 'Fence': 'G',
 'SalePrice': 250000,
 'Sold': 'Y'}
appenddata2={ 'LotArea': 15000,
 'Street': "Gravel",
 'NeighborArea': "Downtown",
 'HouseStyle':  '1Story',
 'YearBuilt': 2019,
 'CentralAir': 'N',
 'Bedroom':  4,
 'Fireplaces': 0,
 'GarageType':  'Attchd',
 'GarageYrBlt':  2019,
 'GarageArea':  250,
 'PoolArea':  0,
 'PoolQC': 'G',
 'Fence':  'G',
 'SalePrice':  195000,
 'Sold': 'Y'}

# %%
data = data.append(appenddata1, ignore_index = True)
data = data.append(appenddata2, ignore_index = True)
data
# Out:
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_12420\1486543564.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = data.append(appenddata1, ignore_index = True)
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_12420\1486543564.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = data.append(appenddata2, ignore_index = True)
#       LotArea  Street  NeighborArea HouseStyle  YearBuilt CentralAir  Bedroom  \
# 0        8450    Pave       CollgCr     2Story       2003          Y        3
# 1        9600    Pave       Veenker     1Story       1976          Y        3
# 2       11250    Pave       CollgCr     2Story       2001          Y        3
# 3        9550    Pave       Crawfor     2Story       1915          Y        3
# ...
